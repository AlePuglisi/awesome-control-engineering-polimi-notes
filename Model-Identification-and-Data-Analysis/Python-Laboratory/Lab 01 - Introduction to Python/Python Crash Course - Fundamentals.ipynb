# %% [markdown]
# # **Statistical Learning for Automation Systems**
#
#
# ## *Prof. Simone Formentin*
#
# ___
#
#
# # Python Crash Course
#
# Please note this is not meant to be a comprehensive overview of Python or programming in general.
#
# This notebook will just go through the basic topics in order:
#
# * Data types
#     * Numbers
#     * Strings
#     * Printing
#     * Lists
#     * Booleans
# * Comparison and Logic Operators
# * range()
# * if,elif, else Statements
# * for Loops
# * while Loops
# ____

# %% [markdown]
# ## Data types
#
# ### Numbers

# %%
1 + 1
# Out:
# 2

# %%
1 * 3
# Out:
# 3

# %%
1 / 2
# Out:
# 0.5

# %%
2 ** 4
# Out:
# 16

# %%
5 % 2
# Out:
# 1

# %%
(2 + 3) * (5 + 5)
# Out:
# 50

# %% [markdown]
# ### Variable Assignment

# %%
# Can not start with number or special characters
name_of_var = 2

# %%
x = 2
y = 3

# %%
z = x + y

# %%
z
# Out:
# 5

# %% [markdown]
# ### Strings

# %%
'single quotes'
# Out:
# 'single quotes'

# %%
"double quotes"
# Out:
# 'double quotes'

# %%
"wrap lot's of other quotes"
# Out:
# "wrap lot's of other quotes"

# %% [markdown]
# ### Printing

# %%
x = 'hello'

# %%
x
# Out:
# 'hello'

# %%
print(x)
# Out:
# hello

# %%
num = 12
name = 'Sam'

# %%
print('My number is: {one}, and my name is: {two}'.format(one=num,two=name))
# Out:
# My number is: 12, and my name is: Sam

# %%
print('My number is: {}, and my name is: {}'.format(num,name))
# Out:
# My number is: 12, and my name is: Sam

# %%
num = float(num)

# %%
print("My number is: %.0f, and my name is: %s"%(num,name))
# Out:
# My number is: 12, and my name is: Sam

# %% [markdown]
# ### Lists

# %%
[1,2,3]
# Out:
# [1, 2, 3]

# %%
['hi',1,[1,2]]
# Out:
# ['hi', 1, [1, 2]]

# %%
my_list = ['a','b','c']
my_list
# Out:
# ['a', 'b', 'c']

# %%
my_list.append('d')
my_list
# Out:
# ['a', 'b', 'c', 'd']

# %%
my_list[0]
# Out:
# 'a'

# %%
my_list[1]
# Out:
# 'b'

# %%
my_list[2:]
# Out:
# ['c', 'd']

# %%
my_list[:1]
# Out:
# ['a']

# %%
my_list[-1]
# Out:
# 'd'

# %%
my_list[0] = 'NEW'

# %%
my_list
# Out:
# ['NEW', 'b', 'c', 'd']

# %% [markdown]
# ### Booleans

# %%
True
# Out:
# True

# %%
assert (bool(1)) == True

# %%
False
# Out:
# False

# %% [markdown]
# ## Comparison and Logic Operators

# %%
1 > 2
# Out:
# False

# %%
1 < 2
# Out:
# True

# %%
1 >= 1
# Out:
# True

# %%
1 <= 4
# Out:
# True

# %%
1 == 1
# Out:
# True

# %%
'hi' == 'bye'
# Out:
# False

# %%
(1 > 2) and (2 < 3)
# Out:
# False

# %%
(1 > 2) or (2 < 3)
# Out:
# True

# %%
(1 == 2) or (2 == 3) or (4 == 4)
# Out:
# True

# %% [markdown]
# ## range()

# %%
list_of_elements = list(range(1,5))

# %%
range(0,5)
# Out:
# range(0, 5)

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# ## if,elif, else Statements

# %%
if 1 < 2:
    print('first')
else:
    print('last')
# Out:
# first

# %%
if 1 > 2:
    print('first')
else:
    print('last')
# Out:
# last

# %%
if 1 == 2:
    print('first')
elif 3 == 3:
    print('middle')
else:
    print('Last')
# Out:
# middle

# %% [markdown]
# ## for Loops

# %%
for i in range(0,5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(0,4):
    print(list_of_elements[i])
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# ## while Loops

# %%
i = 1
while i < 5:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
