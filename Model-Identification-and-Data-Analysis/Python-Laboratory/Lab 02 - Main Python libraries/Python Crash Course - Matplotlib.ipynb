# %% [markdown]
# # **Statistical Learning for Automation Systems**
#
#
# ## *Prof. Simone Formentin*
#
# ___
#
# # Matplotlib Overview

# %% [markdown]
# ## Introduction

# %% [markdown]
# Matplotlib is the "grandfather" library of data visualization with Python. It was created by John Hunter. He created it to try to replicate MatLab's plotting capabilities in Python.
#
# It is an excellent 2D and 3D graphics library for generating scientific figures.
#
# Some of the major pros of Matplotlib are:
#
# * Generally easy to get started for simple plots
# * Support for custom labels and texts
# * High-quality output in many formats
# * Very customizable in general
#
#
#
#
# ## Importing

# %% [markdown]
# Import the `matplotlib.pyplot` module under the name `plt`:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# You'll also need to use this line to see plots in the notebook:

# %%
# %matplotlib inline

# %% [markdown]
# That line is only for jupyter notebooks, if you are using another editor, you'll use: **plt.show()** at the end of all your plotting commands to have the figure pop up in another window.

# %% [markdown]
# # Basic Example

# %% [markdown]
# Let's walk through a very simple example using two numpy arrays. You can also use lists, but most likely you'll be passing numpy arrays or pandas columns (which essentially also behave like arrays).

# %%
import numpy as np
x = np.arange(0, 5, 0.5)
y = x ** 2
y2 = np.exp(x)# ** 3

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25])

# %% [markdown]
# ## Basic Matplotlib Commands

# %%
plt.plot(x, y, label='function 1')
plt.plot(x, y2, label='function 2')
plt.legend()

# %%
plt.plot(x, y, 'r--')           # 'r--' stands for 'red dashed line'

plt.xlabel('X Axis Label')
plt.ylabel('Y Axis Label')
plt.title('Plot Title')

#plt.xlim([0,5])
plt.ylim([0,25])
plt.margins(x=0)

# %%
# Multiple plots in the same figure

plt.plot(x, y, 'r--') 
plt.plot(y, x, 'b') 

plt.xlabel('X Axis Label')
plt.ylabel('Y Axis Label')
plt.title('Plot Title')
# Out:
# Text(0.5, 1.0, 'Plot Title')

# %%
# Add a legend

plt.plot(x, y, 'r--', label = 'y') 
plt.plot(y, x, 'b--', label = 'x') 

plt.xlabel('X Axis Label')
plt.ylabel('Y Axis Label')
plt.title('Plot Title')

plt.legend()

# %% [markdown]
# ## Creating Multiplots on Same Canvas

# %%
# plt.subplot(nrows, ncols, plot_number)
plt.subplot(1,2,1)
plt.plot(x, y, 'r--') 
plt.subplot(1,2,2)
plt.plot(y, x, 'g*-');

# %%
# Add title and labels for each plot

# plt.subplot(nrows, ncols, plot_number)
plt.subplot(1,2,1)
plt.plot(x, y, 'r--') 
plt.xlabel('X Axis Label')
plt.ylabel('Y Axis Label')
plt.title('Plot 1 Title')
plt.subplot(1,2,2)
plt.plot(y, x, 'g*-');
plt.xlabel('X Axis Label')
plt.ylabel('Y Axis Label')
plt.title('Plot 2 Title')
# Out:
# Text(0.5, 1.0, 'Plot 2 Title')

# %% [markdown]
# ### Figure size, aspect ratio and DPI

# %% [markdown]
# Matplotlib allows the aspect ratio, DPI and figure size to be specified when the Figure object is created. You can use the `figsize` and `dpi` keyword arguments.
# * `figsize` is a tuple of the width and height of the figure in inches
# * `dpi` is the dots-per-inch (pixel per inch).
#
# For example:

# %%
plt.figure(figsize=(8,4), dpi=100)

plt.plot(x, y, 'r--', label = 'y') 
plt.plot(y, x, 'b--', label = 'x') 

plt.xlabel('X Axis Label')
plt.ylabel('Y Axis Label')
plt.title('Plot Title')
plt.grid(True)

plt.legend()
plt.show()

# %% [markdown]
# ## Saving figures
# Matplotlib can generate high-quality output in a number formats, including PNG, JPG, EPS, SVG, PGF and PDF.

# %% [markdown]
# To save a figure to a file we can use the `savefig` method in the `Figure` class:

# %% [markdown]
# plt.savefig("filename.png")

# %%
plt.plot(x, y, 'r--', label = 'y') 
plt.plot(y, x, 'b--', label = 'x') 

plt.xlabel('X Axis Label')
plt.ylabel('Y Axis Label')
plt.title('Plot Title')

plt.legend()

plt.savefig("figure.png")

# %% [markdown]
# Here we can also optionally specify the DPI and choose between different output formats:

# %% [markdown]
# plt.savefig("figure.png", dpi=200)

# %% [markdown]
# # Special Plot Types
#
# There are many specialized plots we can create, such as barplots, histograms, scatter plots, and much more. Most of these type of plots we will actually create using seaborn, a statistical plotting library for Python. But here are a few examples of these type of plots:

# %%
# Scatterplot
plt.scatter(x,y)

# %%
# Histplot

from random import sample
data = sample(range(1, 1000), 100)
len(data)#.shape
# Out:
# 100

# %%
plt.hist(data, 30)
# Out:
# (array([4., 3., 1., 6., 4., 4., 6., 6., 3., 2., 5., 2., 3., 5., 2., 7., 4.,
#         2., 3., 2., 3., 2., 6., 3., 0., 3., 2., 3., 2., 2.]),
#  array([  3.        ,  35.86666667,  68.73333333, 101.6       ,
#         134.46666667, 167.33333333, 200.2       , 233.06666667,
#         265.93333333, 298.8       , 331.66666667, 364.53333333,
#         397.4       , 430.26666667, 463.13333333, 496.        ,
#         528.86666667, 561.73333333, 594.6       , 627.46666667,
#         660.33333333, 693.2       , 726.06666667, 758.93333333,
#         791.8       , 824.66666667, 857.53333333, 890.4       ,
#         923.26666667, 956.13333333, 989.        ]),
#  <BarContainer object of 30 artists>)

# %%
# Boxplot
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# rectangular box plot
plt.boxplot(data,vert=True);

# %% [markdown]
# ## Further reading

# %% [markdown]
# * http://www.matplotlib.org - The project web page for matplotlib.
# * http://matplotlib.org/gallery.html - A large gallery showcaseing various types of plots matplotlib can create. Highly recommended!
